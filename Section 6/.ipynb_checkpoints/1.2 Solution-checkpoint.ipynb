# %% [markdown]
# # Exercise 1:
#
# Here we shall be practising some quick pandas skills using various skills that we have learned in the previous lectures.
#
# We will be using the [Weather Data](https://www.kaggle.com/zaraavagyan/weathercsv/) from Kaggle!
# Just follow along and complete the tasks outlined in bold below.

# %%
import pandas as pd

# %% [markdown]
# #### Read the dataset "weather.csv"

# %%
d = pd.read_csv('weather.csv')

# %% [markdown]
# #### Check the data structure of each of the columns using info() command:

# %%
d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 366 entries, 0 to 365
# Data columns (total 22 columns):
# MinTemp          366 non-null float64
# MaxTemp          366 non-null float64
# Rainfall         366 non-null float64
# Evaporation      366 non-null float64
# Sunshine         363 non-null float64
# WindGustDir      363 non-null object
# WindGustSpeed    364 non-null float64
# WindDir9am       335 non-null object
# WindDir3pm       365 non-null object
# WindSpeed9am     359 non-null float64
# WindSpeed3pm     366 non-null int64
# Humidity9am      366 non-null int64
# Humidity3pm      366 non-null int64
# Pressure9am      366 non-null float64
# Pressure3pm      366 non-null float64
# Cloud9am         366 non-null int64
# Cloud3pm         366 non-null int64
# Temp9am          366 non-null float64
# Temp3pm          366 non-null float64
# RainToday        366 non-null object
# RISK_MM          366 non-null float64
# RainTomorrow     366 non-null object
# ...

# %% [markdown]
# #### How many rows and columns are there in d?

# %%
d.shape
# Out:
# (366, 22)

# %% [markdown]
# #### See the first five rows:

# %%
d.head()
# Out:
#    MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0      8.0     24.3       0.0          3.4       6.3          NW
# 1     14.0     26.9       3.6          4.4       9.7         ENE
# 2     13.7     23.4       3.6          5.8       3.3          NW
# 3     13.3     15.5      39.8          7.2       9.1          NW
# 4      7.6     16.1       2.8          5.6      10.6         SSE
#
#    WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 0           30.0         SW         NW           6.0  ...           29
# 1           39.0          E          W           4.0  ...           36
# 2           85.0          N        NNE           6.0  ...           69
# 3           54.0        WNW          W          30.0  ...           56
# 4           50.0        SSE        ESE          20.0  ...           49
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# ...

# %% [markdown]
# #### See the first nine rows this time:

# %%
d.head(9)
# Out:
#    MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0      8.0     24.3       0.0          3.4       6.3          NW
# 1     14.0     26.9       3.6          4.4       9.7         ENE
# 2     13.7     23.4       3.6          5.8       3.3          NW
# 3     13.3     15.5      39.8          7.2       9.1          NW
# 4      7.6     16.1       2.8          5.6      10.6         SSE
# 5      6.2     16.9       0.0          5.8       8.2          SE
# 6      6.1     18.2       0.2          4.2       8.4          SE
# 7      8.3     17.0       0.0          5.6       4.6           E
# 8      8.8     19.5       0.0          4.0       4.1           S
#
#    WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 0           30.0         SW         NW           6.0  ...           29
# 1           39.0          E          W           4.0  ...           36
# 2           85.0          N        NNE           6.0  ...           69
# ...

# %% [markdown]
# #### See the last five rows:

# %%
d.tail()
# Out:
#      MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 361      9.0     30.7       0.0          7.6      12.1         NNW
# 362      7.1     28.4       0.0         11.6      12.7           N
# 363     12.5     19.9       0.0          8.4       5.3         ESE
# 364     12.5     26.9       0.0          5.0       7.1          NW
# 365     12.3     30.2       0.0          6.0      12.6          NW
#
#      WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 361           76.0        SSE         NW           7.0  ...           15
# 362           48.0        NNW        NNW           2.0  ...           22
# 363           43.0        ENE        ENE          11.0  ...           47
# 364           46.0        SSW        WNW           6.0  ...           39
# 365           78.0         NW        WNW          31.0  ...           13
#
#      Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  \
# ...

# %% [markdown]
# #### Suppose you want to get 10 rows of the dataframe ranging from row 20 to 30. How will you get that?

# %%
d[20:31]
# Out:
#     MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 20     15.3     33.4       0.0          8.8       9.5         WNW
# 21     16.4     19.4       0.4          9.2       0.0           E
# 22     12.8     18.5      25.8          2.8       0.6         ESE
# 23     12.0     24.3       0.4          1.2       7.5         NNE
# 24     15.4     28.4       0.0          4.4       8.1         ENE
# 25     15.6     26.9       0.0          6.8       8.9           E
# 26     13.3     22.2       0.2          6.6       2.3         ENE
# 27     12.9     28.0       0.0          4.4      10.7           S
# 28     15.1     24.3       0.0          7.0       0.4          SE
# 29     13.6     24.1       0.4          2.6       0.5         NNW
# 30     15.1     20.4      22.6          2.4       0.2         SSE
#
#     WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 20           59.0          N         NW           2.0  ...           26
# ...

# %% [markdown]
# #### See the first 10 rows of 'Rainfall' column:

# %%
d['Rainfall'].head(10)
# Out:
# 0     0.0
# 1     3.6
# 2     3.6
# 3    39.8
# 4     2.8
# 5     0.0
# 6     0.2
# 7     0.0
# 8     0.0
# 9    16.2
# Name: Rainfall, dtype: float64

# %% [markdown]
# #### See the minimum value taken by the variable `Rainfall`

# %%
d['Rainfall'].min()
# Out:
# 0.0

# %% [markdown]
# #### See the maximum value taken by the variable `Rainfall`

# %%
d['Rainfall'].max()
# Out:
# 39.8

# %% [markdown]
# #### See the mean value of the variable `Rainfall`

# %%
d['Rainfall'].mean()

# %% [markdown]
# ### Get the following statistics of your dataframe

# %%
d.describe()
# Out:
#           MinTemp     MaxTemp    Rainfall  Evaporation    Sunshine  \
# count  366.000000  366.000000  366.000000   366.000000  363.000000
# mean     7.265574   20.550273    1.428415     4.521858    7.909366
# std      6.025800    6.690516    4.225800     2.669383    3.481517
# min     -5.300000    7.600000    0.000000     0.200000    0.000000
# 25%      2.300000   15.025000    0.000000     2.200000    5.950000
# 50%      7.450000   19.650000    0.000000     4.200000    8.600000
# 75%     12.500000   25.500000    0.200000     6.400000   10.500000
# max     20.900000   35.800000   39.800000    13.800000   13.600000
#
#        WindGustSpeed  WindSpeed9am  WindSpeed3pm  Humidity9am  Humidity3pm  \
# count     364.000000    359.000000    366.000000   366.000000   366.000000
# mean       39.840659      9.651811     17.986339    72.035519    44.519126
# std        13.059807      7.951929      8.856997    13.137058    16.850947
# ...

# %% [markdown]
# ## Indexing and Slicing:

# %%
d.head()
# Out:
#    MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0      8.0     24.3       0.0          3.4       6.3          NW
# 1     14.0     26.9       3.6          4.4       9.7         ENE
# 2     13.7     23.4       3.6          5.8       3.3          NW
# 3     13.3     15.5      39.8          7.2       9.1          NW
# 4      7.6     16.1       2.8          5.6      10.6         SSE
#
#    WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 0           30.0         SW         NW           6.0  ...           29
# 1           39.0          E          W           4.0  ...           36
# 2           85.0          N        NNE           6.0  ...           69
# 3           54.0        WNW          W          30.0  ...           56
# 4           50.0        SSE        ESE          20.0  ...           49
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# ...

# %% [markdown]
# #### Filter the 5th row of dataframe

# %%
d.loc[5]
# Out:
# MinTemp             6.2
# MaxTemp            16.9
# Rainfall              0
# Evaporation         5.8
# Sunshine            8.2
# WindGustDir          SE
# WindGustSpeed        44
# WindDir9am           SE
# WindDir3pm            E
# WindSpeed9am         20
# WindSpeed3pm         24
# Humidity9am          70
# Humidity3pm          57
# Pressure9am      1023.8
# Pressure3pm      1021.7
# Cloud9am              7
# Cloud3pm              5
# Temp9am            10.9
# Temp3pm            14.8
# RainToday            No
# RISK_MM             0.2
# RainTomorrow         No
# Name: 5, dtype: object

# %% [markdown]
# #### What is the difference in `loc` and `iloc` methods of indexing?

# %% [markdown]
# ## Pivot Table:

# %%
mydis={
    'Date':['5/1/2017','5/2/2017','5/3/2017','5/1/2017','5/2/2017','5/3/2017','5/1/2017','5/2/2017','5/3/2017'],
    'city':['new york','new york','new york','mumbai','mumbai','mumbai','beijing','beijing','beijing'],
    'temp':[65,66,68,75,78,82,80,77,79],
'humidity':[56,58,60,80,83,85,26,30,35]
}
df=pd.DataFrame(mydis)
df
# Out:
#        Date      city  temp  humidity
# 0  5/1/2017  new york    65        56
# 1  5/2/2017  new york    66        58
# 2  5/3/2017  new york    68        60
# 3  5/1/2017    mumbai    75        80
# 4  5/2/2017    mumbai    78        83
# 5  5/3/2017    mumbai    82        85
# 6  5/1/2017   beijing    80        26
# 7  5/2/2017   beijing    77        30
# 8  5/3/2017   beijing    79        35

# %% [markdown]
# #### Draw a pivot table with date on index and city on columns:

# %%
df.pivot(index='Date',columns='city')
# Out:
#             temp                 humidity
# city     beijing mumbai new york  beijing mumbai new york
# Date
# 5/1/2017      80     75       65       26     80       56
# 5/2/2017      77     78       66       30     83       58
# 5/3/2017      79     82       68       35     85       60

# %% [markdown]
# #### Draw a pivot table with date on index and city on columns and just humidity values:

# %%
df.pivot(index='Date',columns='city' , values = ['humidity'])
# Out:
#          humidity
# city      beijing mumbai new york
# Date
# 5/1/2017       26     80       56
# 5/2/2017       30     83       58
# 5/3/2017       35     85       60

# %% [markdown]
# ## Merging:
#
# Let's say we have the datasets as given below:

# %%
# Dataset one is for the temperature for corresponding dates: 
temp1={
      "date":['01-02-12','03-02-12','04-02-12','05-02-12'],
      "event":['sunny','cold','cold','rainy'],
      "temp":[14,16,15,10]
}
temp=pd.DataFrame(temp1)
temp
# Out:
#        date  event  temp
# 0  01-02-12  sunny    14
# 1  03-02-12   cold    16
# 2  04-02-12   cold    15
# 3  05-02-12  rainy    10

# %%
# Dataset 2 is for additional weather related variables like wind speed and weather type like sunny, cold or rainy: 
ws={
      "date":['01-02-12','03-02-12','04-02-12','05-02-12'],
      "event":['sunny','cold','cold','rainy'],
      "wind-speed":[12,10,9,14],
}
wind_speed=pd.DataFrame(ws)
wind_speed
# Out:
#        date  event  wind-speed
# 0  01-02-12  sunny          12
# 1  03-02-12   cold          10
# 2  04-02-12   cold           9
# 3  05-02-12  rainy          14

# %% [markdown]
# #### Join the temp and ws datasets on the basis of dates:

# %%
df=pd.merge(temp,wind_speed,on=['date','event'])
df
# Out:
#        date  event  temp  wind-speed
# 0  01-02-12  sunny    14          12
# 1  03-02-12   cold    16          10
# 2  04-02-12   cold    15           9
# 3  05-02-12  rainy    10          14

# %% [markdown]
# #### Join the temp and ws datasets on the basis of dates:

# %% [markdown]
# Good Job! One more to go.
